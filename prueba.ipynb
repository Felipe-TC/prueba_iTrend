# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.plot(x, y)
plt.title("Señal senoidal de prueba")
plt.show()
print("Este es un grafico senoidal")
# Out:
# Este es un grafico senoidal
